# %%
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from keras.layers import Activation, Dropout, BatchNormalization, Flatten, Dense

from keras.models import Sequential, Model
#rom keras.applications.xception import Xception
#from keras.applications.resnet50 import ResNet50
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.optimizers import Adam, SGD, RMSprop

import tensorflow as tf

import os
import numpy as np
import pandas as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DATASET_DIR = "../input/covid-19-x-ray-10000-images/dataset"

IMG_W = 150
IMG_H = 150
CHANNELS = 3

INPUT_SHAPE = (IMG_W, IMG_H, CHANNELS)
NB_CLASSES = 2
EPOCHS = 15
BATCH_SIZE = 4

# %%
os.listdir(DATASET_DIR)
# Out:
# ['covid', 'normal']

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=INPUT_SHAPE))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])
#model.compile(Adam(lr=0.0001),loss="binary_crossentropy", metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_73 (Conv2D)           (None, 148, 148, 32)      896
# _________________________________________________________________
# activation_121 (Activation)  (None, 148, 148, 32)      0
# _________________________________________________________________
# max_pooling2d_73 (MaxPooling (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_74 (Conv2D)           (None, 72, 72, 32)        9248
# _________________________________________________________________
# activation_122 (Activation)  (None, 72, 72, 32)        0
# _________________________________________________________________
# max_pooling2d_74 (MaxPooling (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_75 (Conv2D)           (None, 34, 34, 64)        18496
# _________________________________________________________________
# activation_123 (Activation)  (None, 34, 34, 64)        0
# _________________________________________________________________
# max_pooling2d_75 (MaxPooling (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_25 (Flatten)         (None, 18496)             0
# _________________________________________________________________
# dense_49 (Dense)             (None, 64)                1183808
# _________________________________________________________________
# activation_124 (Activation)  (None, 64)                0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_50 (Dense)             (None, 1)                 65
# _________________________________________________________________
# activation_125 (Activation)  (None, 1)                 0
# =================================================================
# Total params: 1,212,513
# Trainable params: 1,212,513
# Non-trainable params: 0
# _________________________________________________________________

# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

normal_images = []
for img_path in glob.glob(DATASET_DIR + '/normal/*'):
    normal_images.append(mpimg.imread(img_path))

fig = plt.figure()
fig.suptitle('normal')
plt.imshow(normal_images[0], cmap='gray')

# %%
covid_images = []
for img_path in glob.glob(DATASET_DIR + '/covid/*'):
    covid_images.append(mpimg.imread(img_path))

fig = plt.figure()
fig.suptitle('covid')
plt.imshow(covid_images[0], cmap='gray')

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.4)

train_generator = train_datagen.flow_from_directory(
    DATASET_DIR,
    target_size=(IMG_H, IMG_W),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='training')

validation_generator = train_datagen.flow_from_directory(
    DATASET_DIR, # same directory as training data
    target_size=(IMG_H, IMG_W),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='validation')

history = model.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // BATCH_SIZE,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // BATCH_SIZE,
    epochs = EPOCHS)
# Out:
# Found 59 images belonging to 2 classes.
# Found 39 images belonging to 2 classes.
# Epoch 1/15
# 14/14 [==============================] - 3s 217ms/step - loss: 0.7333 - accuracy: 0.6364 - val_loss: 0.7279 - val_accuracy: 0.7222
# Epoch 2/15
# 14/14 [==============================] - 4s 286ms/step - loss: 0.5683 - accuracy: 0.7636 - val_loss: 0.6143 - val_accuracy: 0.7714
# Epoch 3/15
# 14/14 [==============================] - 4s 259ms/step - loss: 0.5106 - accuracy: 0.7636 - val_loss: 0.2249 - val_accuracy: 0.9429
# Epoch 4/15
# 14/14 [==============================] - 3s 245ms/step - loss: 0.3042 - accuracy: 0.8545 - val_loss: 0.0439 - val_accuracy: 0.8857
# Epoch 5/15
# 14/14 [==============================] - 4s 253ms/step - loss: 0.3618 - accuracy: 0.8750 - val_loss: 0.4269 - val_accuracy: 0.8857
# Epoch 6/15
# 14/14 [==============================] - 3s 229ms/step - loss: 0.1172 - accuracy: 0.9636 - val_loss: 0.0058 - val_accuracy: 0.9714
# Epoch 7/15
# 14/14 [==============================] - 3s 202ms/step - loss: 0.3826 - accuracy: 0.8889 - val_loss: 0.2312 - val_accuracy: 0.9143
# Epoch 8/15
# 14/14 [==============================] - 3s 189ms/step - loss: 0.2765 - accuracy: 0.8929 - val_loss: 0.0127 - val_accuracy: 0.7714
# Epoch 9/15
# 14/14 [==============================] - 3s 180ms/step - loss: 0.3153 - accuracy: 0.8364 - val_loss: 0.1142 - val_accuracy: 0.9143
# Epoch 10/15
# 14/14 [==============================] - 3s 180ms/step - loss: 0.2981 - accuracy: 0.9444 - val_loss: 0.0346 - val_accuracy: 0.9429
# Epoch 11/15
# 14/14 [==============================] - 3s 200ms/step - loss: 0.0810 - accuracy: 0.9643 - val_loss: 0.1077 - val_accuracy: 0.8333
# Epoch 12/15
# 14/14 [==============================] - 4s 262ms/step - loss: 0.1986 - accuracy: 0.9444 - val_loss: 0.0026 - val_accuracy: 0.9429
# Epoch 13/15
# 14/14 [==============================] - 3s 218ms/step - loss: 0.1151 - accuracy: 0.9286 - val_loss: 0.0400 - val_accuracy: 0.9714
# Epoch 14/15
# 14/14 [==============================] - 3s 190ms/step - loss: 0.0823 - accuracy: 0.9273 - val_loss: 0.0243 - val_accuracy: 0.9429
# Epoch 15/15
# 14/14 [==============================] - 3s 181ms/step - loss: 0.2904 - accuracy: 0.8727 - val_loss: 0.1877 - val_accuracy: 0.9143

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
